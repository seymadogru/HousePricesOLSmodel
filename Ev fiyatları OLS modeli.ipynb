# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
house_prices_df = pd.read_csv("house_prices_train.csv")
house_prices_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
new_features = house_prices_df[["YearBuilt","LotArea","TotRmsAbvGrd","FullBath","MoSold","HalfBath","GarageCars","SalePrice"]]
new_features
# Out:
#       YearBuilt  LotArea  TotRmsAbvGrd  FullBath  MoSold  HalfBath  \
# 0          2003     8450             8         2       2         1
# 1          1976     9600             6         2       5         0
# 2          2001    11250             6         2       9         1
# 3          1915     9550             7         1       2         0
# 4          2000    14260             9         2      12         1
# ...         ...      ...           ...       ...     ...       ...
# 1455       1999     7917             7         2       8         1
# 1456       1978    13175             7         2       2         0
# 1457       1941     9042             9         2       5         0
# 1458       1950     9717             5         1       4         0
# 1459       1965     9937             6         1       6         1
#
#       GarageCars  SalePrice
# 0              2     208500
# 1              2     181500
# 2              2     223500
# 3              3     140000
# ...

# %%
Y = new_features['SalePrice']
X = new_features[['YearBuilt','LotArea','MoSold','TotRmsAbvGrd','FullBath','HalfBath','GarageCars']]
lrm = linear_model.LinearRegression()
lrm.fit(X, Y)
# Out:
# LinearRegression()

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     316.0
# Date:                Thu, 02 Dec 2021   Prob (F-statistic):          1.83e-286
# Time:                        19:17:48   Log-Likelihood:                -17868.
# No. Observations:                1460   AIC:                         3.575e+04
# Df Residuals:                    1452   BIC:                         3.580e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# --İstatistiksel olarak p valuelara baktığımızda MoSold ve HalfBath feature'larının hedef değişken için anlamsız bir değişken olduğunu görüyoruz.

# %%
Y = new_features['SalePrice']
X = new_features[['YearBuilt','LotArea','TotRmsAbvGrd','FullBath','GarageCars']]
lrm = linear_model.LinearRegression()
lrm.fit(X, Y)
# Out:
# LinearRegression()

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     441.3
# Date:                Thu, 02 Dec 2021   Prob (F-statistic):          2.25e-288
# Time:                        19:18:00   Log-Likelihood:                -17870.
# No. Observations:                1460   AIC:                         3.575e+04
# Df Residuals:                    1454   BIC:                         3.578e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# Bu MoSold değişkenini ve halfBath değişkeninini çıkarttığımızda R-squared değeri anlamlı derecede değişmedi.

# %% [markdown]
# Katsayılara baktığımızda ev fiyatları üzerinde en çok söz sahibi olan değişken GarageCars (3.293e+04) değişkeni. LotArea'nın katsayısına bakıldığında , diğerlerine göre daha az katkı sağladığı görülmekte.

# %% [markdown]
# Sonuçlar mantıklı ancak bence yeterli değil. R-Squared değerinin Yüzde 70'in üzerine çıkmış olması daha çok işimize gelirdi. Ancak MoSold değişkenini çıkardığımda R-Squared değerinin az da olsa yükselmesini beklemiştim.
